# %%
import subprocess
import os
from IPython.display import display
from matplotlib import pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
from jupyterthemes import jtplot
jtplot.style()

# %%
def call(n, r, threads, save=True):
    path = 'D:/Workspace/BSU-Parallel-Computing/Lab1/Lab1/x64/Debug/Lab1.exe'
    s = 1 if save else 0
    return subprocess.call(path+f' {n} {n} {n} {r} {threads} {s}')

def test(n_range, r_range, threads, verbose=False):
    vals = np.zeros((len(n_range),len(r_range)))
    for i, n in enumerate(n_range):
        for j, r in enumerate(r_range):
            if verbose: 
                print(f"n = {n}; r = {r}; threads = {threads}")
            to_validate = n<1000
            vals[i,j] = call(n, r, threads, save=to_validate)
            if to_validate and not validate():
                print('Error!')
                return
    return vals

def validate():
    path = 'D:/Workspace/BSU-Parallel-Computing/Lab1'
    fpath = os.path.join(path,'A.txt')
    A = np.loadtxt(fpath, dtype=int, skiprows=1)
    fpath = os.path.join(path,'B.txt')
    B = np.loadtxt(fpath, dtype=int, skiprows=1)
    fpath = os.path.join(path,'C.txt')
    C = np.loadtxt(fpath, dtype=int, skiprows=1)
    return np.all(np.dot(A, B) == C)

# %%
n_range = [500, 1000, 1500, 2000, 2500][:-1]
r_range = [1, 2, 5, 10, 25, 50, 100, 200]
t_range = [1, 2, 4]

# %%
for threads in t_range:
    vals = test(n_range, r_range, threads, verbose=True)

    display(pd.DataFrame(data=vals, index=n_range, columns=r_range))

    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(*np.meshgrid(r_range, n_range), vals,
                    cmap=cm.coolwarm, linewidth=1, antialiased=False)
    ax.set_xlabel('Block Size',labelpad=10)
    ax.set_xticks(r_range)
    ax.set_ylabel('Matrix Size',labelpad=10)
    ax.set_yticks(n_range)
    ax.set_zlabel('Computation Time',labelpad=10)

    plt.show()
# Out:
# n = 500; r = 1; threads = 1
# n = 500; r = 2; threads = 1
# n = 500; r = 5; threads = 1
# n = 500; r = 10; threads = 1
# n = 500; r = 25; threads = 1
# n = 500; r = 50; threads = 1
# n = 500; r = 100; threads = 1
# n = 500; r = 200; threads = 1
# n = 1000; r = 1; threads = 1
# n = 1000; r = 2; threads = 1
# n = 1000; r = 5; threads = 1
# n = 1000; r = 10; threads = 1
# n = 1000; r = 25; threads = 1
# n = 1000; r = 50; threads = 1
# n = 1000; r = 100; threads = 1
# n = 1000; r = 200; threads = 1
# n = 1500; r = 1; threads = 1
# n = 1500; r = 2; threads = 1
# n = 1500; r = 5; threads = 1
# n = 1500; r = 10; threads = 1
# n = 1500; r = 25; threads = 1
# n = 1500; r = 50; threads = 1
# n = 1500; r = 100; threads = 1
# n = 1500; r = 200; threads = 1
# n = 2000; r = 1; threads = 1
# n = 2000; r = 2; threads = 1
# n = 2000; r = 5; threads = 1
# n = 2000; r = 10; threads = 1
# n = 2000; r = 25; threads = 1
# n = 2000; r = 50; threads = 1
# n = 2000; r = 100; threads = 1
# n = 2000; r = 200; threads = 1
#            1         2        5        10       25       50       100      200
# 500    15476.0    3791.0   2124.0   1533.0   1435.0   1810.0   1856.0   2131.0
# 1000  128143.0   25247.0  11093.0  15775.0  12573.0  10853.0   9582.0   9181.0
# 1500  401130.0   89830.0  36755.0  31066.0  27850.0  28539.0  30462.0  32011.0
# 2000  929468.0  203971.0  86026.0  73700.0  69503.0  76783.0  74711.0  78262.0
# n = 500; r = 1; threads = 2
# n = 500; r = 2; threads = 2
# n = 500; r = 5; threads = 2
# n = 500; r = 10; threads = 2
# n = 500; r = 25; threads = 2
# n = 500; r = 50; threads = 2
# n = 500; r = 100; threads = 2
# n = 500; r = 200; threads = 2
# n = 1000; r = 1; threads = 2
# n = 1000; r = 2; threads = 2
# n = 1000; r = 5; threads = 2
# n = 1000; r = 10; threads = 2
# n = 1000; r = 25; threads = 2
# n = 1000; r = 50; threads = 2
# n = 1000; r = 100; threads = 2
# n = 1000; r = 200; threads = 2
# n = 1500; r = 1; threads = 2
# n = 1500; r = 2; threads = 2
# n = 1500; r = 5; threads = 2
# n = 1500; r = 10; threads = 2
# n = 1500; r = 25; threads = 2
# n = 1500; r = 50; threads = 2
# n = 1500; r = 100; threads = 2
# n = 1500; r = 200; threads = 2
# n = 2000; r = 1; threads = 2
# n = 2000; r = 2; threads = 2
# n = 2000; r = 5; threads = 2
# n = 2000; r = 10; threads = 2
# n = 2000; r = 25; threads = 2
# n = 2000; r = 50; threads = 2
# n = 2000; r = 100; threads = 2
# n = 2000; r = 200; threads = 2
#            1         2        5        10       25       50       100      200
# 500     8403.0    1947.0    793.0    823.0    661.0    726.0    895.0   1130.0
# 1000   63700.0   17438.0   7843.0   6286.0   5427.0   5373.0   6136.0   7100.0
# 1500  231657.0   54342.0  25208.0  21365.0  20232.0  19916.0  21910.0  24026.0
# 2000  571515.0  120347.0  53472.0  47055.0  46643.0  48037.0  48401.0  50800.0
# n = 500; r = 1; threads = 4
# n = 500; r = 2; threads = 4
# n = 500; r = 5; threads = 4
# n = 500; r = 10; threads = 4
# n = 500; r = 25; threads = 4
# n = 500; r = 50; threads = 4
# n = 500; r = 100; threads = 4
# n = 500; r = 200; threads = 4
# n = 1000; r = 1; threads = 4
# n = 1000; r = 2; threads = 4
# n = 1000; r = 5; threads = 4
# n = 1000; r = 10; threads = 4
# n = 1000; r = 25; threads = 4
# n = 1000; r = 50; threads = 4
# n = 1000; r = 100; threads = 4
# n = 1000; r = 200; threads = 4
# n = 1500; r = 1; threads = 4
# n = 1500; r = 2; threads = 4
# n = 1500; r = 5; threads = 4
# n = 1500; r = 10; threads = 4
# n = 1500; r = 25; threads = 4
# n = 1500; r = 50; threads = 4
# n = 1500; r = 100; threads = 4
# n = 1500; r = 200; threads = 4
# n = 2000; r = 1; threads = 4
# n = 2000; r = 2; threads = 4
# n = 2000; r = 5; threads = 4
# n = 2000; r = 10; threads = 4
# n = 2000; r = 25; threads = 4
# n = 2000; r = 50; threads = 4
# n = 2000; r = 100; threads = 4
# n = 2000; r = 200; threads = 4
#            1        2        5        10       25       50       100      200
# 500     5001.0   1218.0    586.0    538.0    495.0    596.0    734.0    735.0
# 1000   40854.0  10468.0   5111.0   4146.0   3996.0   4558.0   4732.0   5436.0
# 1500  145995.0  34081.0  16555.0  14711.0  13586.0  14668.0  14162.0  15107.0
# 2000  386632.0  88267.0  38521.0  35492.0  34087.0  34015.0  35132.0  41498.0
